# %%
import numpy as np 
import cv2 
import matplotlib.pyplot as plt
# %matplotlib inline

import skimage
# Out:
# C:\Users\sasik\anaconda3\Lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,

# %%
parkir =cv2.imread("ganjil.jpg")

# %%
cv2.imshow("gambar parkir", parkir)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
gray = cv2.cvtColor(parkir, cv2.COLOR_BGR2GRAY)
edges= cv2.Canny(parkir,100,150)

# %%
cv2.imshow("gambar parkir", edges)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
fig,axs = plt.subplots(1,2,figsize=(10,10))
ax = axs.ravel()

ax[0].imshow(gray, cmap='gray')
ax[0].set_title("Gambar Asli")

ax[1].imshow(edges, cmap='gray')
ax[1].set_title("Gambar yang udah dideteksi")
# Out:
# Text(0.5, 1.0, 'Gambar yang udah dideteksi')

# %%
lines = cv2.HoughLinesP(edges, 1, np.pi/180, 100, minLineLength=50, maxLineGap=20)
image_line = parkir.copy()

# %%
for line in lines:
    x1, y1, x2, y2 = line[0]
    cv2.line(image_line, (x1, y1), (x2, y2), (207,107,169),1)

# %%
fig,axs = plt.subplots(1,2,figsize=(10,10))
ax = axs.ravel()

ax[0].imshow(gray, cmap='gray')
ax[0].set_title("Gambar Asli")

ax[1].imshow(image_line, cmap='gray')
ax[1].set_title("Gambar yang udah dideteksi")
# Out:
# Text(0.5, 1.0, 'Gambar yang udah dideteksi')

# %%
# Out:
# array([[  0,   0,   0, ...,   0, 255,   0],
#        [  0,   0,   0, ...,   0, 255,   0],
#        [  0,   0,   0, ...,   0,   0, 255],
#        ...,
#        [  0, 255, 255, ...,   0, 255, 255],
#        [255,   0,   0, ...,   0,   0,   0],
#        [  0,   0, 255, ..., 255,   0,   0]], dtype=uint8)

# %%
lines
# Out:
# array([[[ 567,  796,  567,   84]],
#
#        [[   0,  788, 1199,  767]],
#
#        [[   0,  298, 1183,  298]],
#
#        ...,
#
#        [[   0,  192, 1199,  192]],
#
#        [[ 143,  212, 1197,  212]],
#
#        [[   1,  191, 1198,  191]]], dtype=int32)

# %%
lines.shape
# Out:
# (545, 1, 4)

# %% [markdown]
# ####
